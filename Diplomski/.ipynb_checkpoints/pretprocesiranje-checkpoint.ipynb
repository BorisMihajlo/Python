# %%
import numpy as np
import pandas as pd
import datetime



earthquake= pd.read_csv('database.csv')



earthquake.drop(['ID'],1, inplace=True)
earthquake.drop(['Source'],1, inplace=True)
earthquake.drop(['Magnitude Source'],1, inplace=True)
earthquake.drop(['Status'],1, inplace=True)
earthquake.drop(['Type'],1, inplace=True)



earthquake=earthquake.replace(np.NaN,0)

earthquake1=earthquake
earthquake1.drop(['Date'],1, inplace=True)
earthquake1.drop(['Time'],1, inplace=True)
earthquake1.drop(['Location Source'],1, inplace=True)
earthquake1.drop(['Magnitude Type'],1, inplace=True)

earthquake1
# Out:
#        Latitude  Longitude   Depth  Depth Error  Depth Seismic Stations  \
# 0       19.2460   145.6160  131.60          0.0                     0.0
# 1        1.8630   127.3520   80.00          0.0                     0.0
# 2      -20.5790  -173.9720   20.00          0.0                     0.0
# 3      -59.0760   -23.5570   15.00          0.0                     0.0
# 4       11.9380   126.4270   15.00          0.0                     0.0
# 5      -13.4050   166.6290   35.00          0.0                     0.0
# 6       27.3570    87.8670   20.00          0.0                     0.0
# 7      -13.3090   166.2120   35.00          0.0                     0.0
# 8      -56.4520   -27.0430   95.00          0.0                     0.0
# 9      -24.5630   178.4870  565.00          0.0                     0.0
# 10      -6.8070   108.9880  227.90          0.0                     0.0
# 11      -2.6080   125.9520   20.00          0.0                     0.0
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(earthquake['Magnitude'], earthquake['Depth'])

# %%
plt.scatter(earthquake['Magnitude'], earthquake['Depth'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import  neighbors, cross_validation
from sklearn.linear_model import LinearRegression


X=earthquake1[['Latitude','Longitude' ,'Depth Error','Depth Seismic Stations','Magnitude','Magnitude Error','Magnitude Seismic Stations','Azimuthal Gap','Horizontal Distance','Horizontal Error']]
y=earthquake1[['Root Mean Square']]

X_train,X_test,y_train,y_test = cross_validation.train_test_split(X,y,test_size=0.2)

len(y_train)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-75-40f2a6773175> in <module>
#       1 from sklearn.model_selection import train_test_split
#       2 from sklearn.neighbors import KNeighborsClassifier
# ----> 3 from sklearn import  neighbors, cross_validation
#       4 from sklearn.linear_model import LinearRegression
#       5
#
# ImportError: cannot import name 'cross_validation' from 'sklearn' (C:\Users\Boris\Anaconda3\lib\site-packages\sklearn\__init__.py)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import neighbors cross_validation 
from sklearn.linear_model import LinearRegression
clf = neighbors.KNeighborsClassifier()
clf.fit(X_train,y_train)
 
preciznost = clf.score(X_test,y_test)
preciznost
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-9b6c22b7f8f1> in <module>
#       3 from sklearn.linear_model import LinearRegression
#       4 clf = neighbors.KNeighborsClassifier()
# ----> 5 clf.fit(X_train,y_train)
#       6
#       7 preciznost = clf.score(X_test,y_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\base.py in fit(self, X, y)
#     904             self.outputs_2d_ = True
#     905
# --> 906         check_classification_targets(y)
#     907         self.classes_ = []
#     908         self._y = np.empty(y.shape, dtype=np.int)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     167     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     168                       'multilabel-indicator', 'multilabel-sequences']:
# ...
